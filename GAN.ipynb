# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# 100%|██████████| 170M/170M [00:12<00:00, 13.2MB/s]

# %%
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
          nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
          nn.LeakyReLU(0.2),
          nn.Dropout(0.25),
          nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
          nn.ZeroPad2d((0, 1, 0, 1)),
          nn.BatchNorm2d(64, momentum=0.82),
          nn.LeakyReLU(0.25),
          nn.Dropout(0.25),
          nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
          nn.BatchNorm2d(128, momentum=0.82),
          nn.LeakyReLU(0.2),
          nn.Dropout(0.25),
          nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
          nn.BatchNorm2d(256, momentum=0.8),
          nn.LeakyReLU(0.25),
          nn.Dropout(0.25),
          nn.Flatten(),
          nn.Linear(256 * 5 * 5, 1),
          nn.Sigmoid()
      )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)

# Binary Cross Entropy loss for adversarial training
adversarial_loss = nn.BCELoss()

# Optimizers
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(beta1, beta2))

# %%
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):

        real_images = batch[0].to(device)

        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)

        real_images = real_images.to(device)

        optimizer_D.zero_grad()

        z = torch.randn(real_images.size(0), latent_dim, device=device)

        fake_images = generator(z)

        real_loss = adversarial_loss(discriminator(real_images), valid)
        fake_loss = adversarial_loss(discriminator(fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()

        optimizer_G.zero_grad()

        gen_images = generator(z)

        g_loss = adversarial_loss(discriminator(gen_images), valid)
        g_loss.backward()
        optimizer_G.step()

        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.3730 Generator Loss: 2.3288
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.3618 Generator Loss: 2.7582
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.4642 Generator Loss: 1.6601
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.1774 Generator Loss: 2.1910
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.1627 Generator Loss: 2.3157
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.2902 Generator Loss: 2.9469
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.4820 Generator Loss: 1.1634
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.4730 Generator Loss: 1.6178
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.4670 Generator Loss: 2.6217
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.3517 Generator Loss: 1.4691
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.3239 Generator Loss: 3.3991
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.6727 Generator Loss: 0.8792
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.4277 Generator Loss: 2.0941
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.8800 Generator Loss: 1.3882
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.6292 Generator Loss: 2.5912
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.3683 Generator Loss: 1.2132
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.2812 Generator Loss: 4.6252
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.4874 Generator Loss: 2.2121
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.5612 Generator Loss: 1.8677
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.3986 Generator Loss: 1.1699
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.5789 Generator Loss: 0.8411
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.6317 Generator Loss: 0.9789
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.4532 Generator Loss: 1.4980
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.4531 Generator Loss: 1.4420
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.2141 Generator Loss: 1.6485
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.9920 Generator Loss: 3.1829
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.3447 Generator Loss: 1.3071
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.2038 Generator Loss: 1.5089
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.2656 Generator Loss: 1.7053
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.8336 Generator Loss: 0.8282
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.5156 Generator Loss: 1.0232
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.6485 Generator Loss: 1.9731
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.2936 Generator Loss: 1.3172
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.3429 Generator Loss: 1.0778
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.5279 Generator Loss: 2.1309
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.5205 Generator Loss: 1.8457
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.2114 Generator Loss: 2.7380
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.5560 Generator Loss: 2.0190
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.5940 Generator Loss: 2.0842
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.4747 Generator Loss: 1.2072
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.3098 Generator Loss: 1.3660
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.2952 Generator Loss: 2.3658
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.5802 Generator Loss: 2.8055
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.5748 Generator Loss: 0.5689
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.6975 Generator Loss: 1.9173
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.2733 Generator Loss: 1.5076
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.5188 Generator Loss: 2.2338
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.6428 Generator Loss: 0.8917
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.5454 Generator Loss: 2.4450
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.3380 Generator Loss: 1.5144
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.6270 Generator Loss: 1.6286
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.3476 Generator Loss: 1.8950
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.2810 Generator Loss: 2.1626
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.6518 Generator Loss: 1.1333
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.6465 Generator Loss: 1.6347
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.4705 Generator Loss: 2.0526
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 1.1114 Generator Loss: 1.2688
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.5300 Generator Loss: 1.1484
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.5410 Generator Loss: 1.3602
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.8472 Generator Loss: 1.8894
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.5729 Generator Loss: 1.5834
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.4595 Generator Loss: 2.7585
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.4600 Generator Loss: 2.3641
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.4171 Generator Loss: 1.5452
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.5719 Generator Loss: 1.2513
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.7348 Generator Loss: 1.7127
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.4702 Generator Loss: 1.9110
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.5037 Generator Loss: 1.2905
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.4512 Generator Loss: 1.4267
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.7245 Generator Loss: 0.9552
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.3770 Generator Loss: 2.2913
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.5937 Generator Loss: 1.4451
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.5741 Generator Loss: 1.3787
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.4473 Generator Loss: 1.3786
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.4708 Generator Loss: 2.1569
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.4836 Generator Loss: 1.2869
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.9746 Generator Loss: 1.3262
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.4359 Generator Loss: 2.5953
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.8276 Generator Loss: 0.8462
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.5533 Generator Loss: 1.9539
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.4424 Generator Loss: 1.9795
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.5786 Generator Loss: 1.8934
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.4450 Generator Loss: 0.9652
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.8830 Generator Loss: 0.9834
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.4184 Generator Loss: 0.9188
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 1.1134 Generator Loss: 1.0940
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.4203 Generator Loss: 1.4440
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.4699 Generator Loss: 1.2780
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.5366 Generator Loss: 0.9443
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.5854 Generator Loss: 1.2556
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.4967 Generator Loss: 1.7381
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.6302 Generator Loss: 2.3915
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.5342 Generator Loss: 0.9202
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.5131 Generator Loss: 1.0245
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.4546 Generator Loss: 1.8164
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.3981 Generator Loss: 1.4457
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.7061 Generator Loss: 1.1202
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.3609 Generator Loss: 1.4900
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.5341 Generator Loss: 1.2377
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.6602 Generator Loss: 1.3694
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.5502 Generator Loss: 1.0985
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.5333 Generator Loss: 1.3531
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.3968 Generator Loss: 1.8397
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.7823 Generator Loss: 1.4790
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.6428 Generator Loss: 1.0580
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.2804 Generator Loss: 2.3103
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.6698 Generator Loss: 0.9866
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.7517 Generator Loss: 1.4947
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 1.0608 Generator Loss: 1.1269
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.2335 Generator Loss: 1.6939
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.5038 Generator Loss: 1.3061
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.3376 Generator Loss: 2.2749
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.3968 Generator Loss: 0.9187
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.5070 Generator Loss: 2.2823
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.3467 Generator Loss: 2.2658
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.6219 Generator Loss: 1.8723
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.7303 Generator Loss: 2.2121
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.4395 Generator Loss: 1.0273
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.4940 Generator Loss: 1.4903
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.4095 Generator Loss: 1.5445
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.5967 Generator Loss: 1.8860
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.5236 Generator Loss: 1.2040
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.5589 Generator Loss: 2.1794
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.4708 Generator Loss: 1.1414
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.4988 Generator Loss: 1.0709
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.5640 Generator Loss: 1.5368
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.4476 Generator Loss: 1.7276
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.3328 Generator Loss: 0.8788
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.5845 Generator Loss: 1.1423
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.4273 Generator Loss: 1.2458
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.5079 Generator Loss: 1.6827
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.6739 Generator Loss: 1.5418
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.4773 Generator Loss: 1.9885
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.9122 Generator Loss: 1.3471
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.2988 Generator Loss: 1.1028
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.4892 Generator Loss: 1.0284
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.4136 Generator Loss: 1.3754
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.4066 Generator Loss: 2.3602
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.5461 Generator Loss: 1.9833
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.4992 Generator Loss: 2.2397
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.4306 Generator Loss: 2.0343
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 1.0299 Generator Loss: 1.1990
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.2433 Generator Loss: 2.2245
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 0.6720 Generator Loss: 1.2364
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.4789 Generator Loss: 0.9947
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.5559 Generator Loss: 1.5752
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.6193 Generator Loss: 1.6102
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.3252 Generator Loss: 2.2033
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 1.2846 Generator Loss: 0.7182
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.4668 Generator Loss: 1.5832

# %%
 with torch.no_grad():
    z = torch.randn(25, latent_dim, device=device)
    generated = generator(z).detach().cpu()
    grid = torchvision.utils.make_grid(generated, nrow=5, normalize=True)
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    plt.axis("off")
    plt.show()
